# %%
from tqdm import tqdm
from skimage import io
from skimage.transform import resize
from skimage.color import rgb2gray
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os
import nrrd
from sklearn.model_selection import train_test_split
import torch
from torch import nn
import torch.nn.functional as F
from sklearn.preprocessing import StandardScaler
from torch.utils import data
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from torchvision import datasets, transforms, models

# %% [markdown]
# #### Load Data

# %%
x_train, header = nrrd.read("../processed/pneumonia_covid/x_train.nrrd")
y_train, header = nrrd.read("../processed/pneumonia_covid/y_train.nrrd")
x_valid, header = nrrd.read("../processed/pneumonia_covid/x_valid.nrrd")
y_valid, header = nrrd.read("../processed/pneumonia_covid/y_valid.nrrd")

# %%
# Transform to torch tensor
tensor_train_x = torch.Tensor(x_train)
tensor_train_y = torch.Tensor(y_train)
tensor_valid_x = torch.Tensor(x_valid)
tensor_valid_y = torch.Tensor(y_valid)

trainset = data.TensorDataset(tensor_train_x, tensor_train_y)
validset = data.TensorDataset(tensor_valid_x, tensor_valid_y)
trainloader = data.DataLoader(trainset, batch_size=5, shuffle=True)
validloader = data.DataLoader(validset, batch_size=5, shuffle=True)

# %% [markdown]
# #### Check for CUDA

# %%
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    device = torch.device("cpu")
    print("Running on CPU")
else:
    device = torch.device("cuda:0")
    print("CUDA is available!")
# Out:
# CUDA is available!

# %%
model = models.densenet121(pretrained=False)

# %%
model.features.conv0 = nn.Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)

# %%
classifier = nn.Sequential(nn.Linear(1024, 256),
                                 nn.ReLU(),
                                 nn.Dropout(0.2),
                                 nn.Linear(256, 2))

model.classifier = classifier

# %%
# Put model on CUDA
model.to(device)
# Out:
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace=True)
#     (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): _Transition(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock2): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): _Transition(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock3): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): _Transition(
#       (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock4): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (norm5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=1024, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=256, out_features=2, bias=True)
#   )
# )

# %%
import torch.optim as optim
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=3, verbose=True)

# %% [markdown]
# #### Train Network

# %%
n_epochs = 200
valid_loss_min = np.Inf
train_losses, valid_losses = [], []

for epoch in range(n_epochs):
    # Define Constants
    train_loss = 0.0
    valid_loss = 0.0
    accuracy = 0.0
    epoch_loss = []
   
    for data, target in trainloader:
        # Put data on GPU
        data, target = data.to(device, dtype=torch.float), target.to(device, dtype=torch.long)
        optimizer.zero_grad()
        output = model(data)
        # Compute loss
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        epoch_loss.append(float(loss.item()*data.size(0)))
        train_loss += loss.item()*data.size(0)
    
    # Check if learning rate needs to be updated
    scheduler.step(np.mean(epoch_loss))
    with torch.no_grad():
        model.eval() # Turn dropout off
        for data, target in validloader:
            data, target = data.to(device, dtype=torch.float), target.to(device, dtype=torch.long)
            output = model(data)
            loss = criterion(output, target)
            valid_loss += loss.item()*data.size(0)
            # Calculating accuracy
            ps = torch.exp(F.log_softmax(output, dim=1))
            top_p, top_class = ps.topk(1, dim=1)
            equals = top_class == target.view(*top_class.shape)
            accuracy += torch.mean(equals.type(torch.FloatTensor))
            
    model.train()
    # Calculate average loss and accuracy
    train_loss = train_loss/len(trainloader)
    valid_loss = valid_loss/len(validloader)
    accuracy = accuracy/len(validloader)
    train_losses.append(train_loss)
    valid_losses.append(valid_loss)
    
    print("Epoch:{}\t Training Loss:{:.6f}\t Validation Loss: {:.6f}\t Accuracy: {:.6f}".format(epoch, train_loss, valid_loss, accuracy))
    # Save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print("Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...".format(valid_loss_min, valid_loss))
        print("-"*40)
        # Save model
        torch.save(model.state_dict(), 'model_checkpoints/densenet121_model_2Class_pn_covid.pth')
        valid_loss_min = valid_loss
# Out:
# Epoch:0	 Training Loss:3.100928	 Validation Loss: 2.573864	 Accuracy: 0.779168
# Validation loss decreased (inf --> 2.573864).  Saving model ...
# ----------------------------------------
# Epoch:1	 Training Loss:2.570252	 Validation Loss: 2.125165	 Accuracy: 0.826668
# Validation loss decreased (2.573864 --> 2.125165).  Saving model ...
# ----------------------------------------
# Epoch:2	 Training Loss:2.269766	 Validation Loss: 2.962766	 Accuracy: 0.739168
# Epoch:3	 Training Loss:2.064990	 Validation Loss: 1.653698	 Accuracy: 0.891668
# Validation loss decreased (2.125165 --> 1.653698).  Saving model ...
# ----------------------------------------
# Epoch:4	 Training Loss:1.801049	 Validation Loss: 13.715409	 Accuracy: 0.545833
# Epoch:5	 Training Loss:1.632230	 Validation Loss: 0.945400	 Accuracy: 0.940001
# Validation loss decreased (1.653698 --> 0.945400).  Saving model ...
# ----------------------------------------
# Epoch:6	 Training Loss:1.504757	 Validation Loss: 1.545946	 Accuracy: 0.898334
# Epoch:7	 Training Loss:1.412221	 Validation Loss: 1.396423	 Accuracy: 0.897501
# Epoch:8	 Training Loss:1.343853	 Validation Loss: 1.389227	 Accuracy: 0.870001
# Epoch:9	 Training Loss:1.306386	 Validation Loss: 0.602910	 Accuracy: 0.962500
# Validation loss decreased (0.945400 --> 0.602910).  Saving model ...
# ----------------------------------------
# Epoch:10	 Training Loss:1.232043	 Validation Loss: 1.951095	 Accuracy: 0.867501
# Epoch:11	 Training Loss:1.137941	 Validation Loss: 0.495406	 Accuracy: 0.970000
# Validation loss decreased (0.602910 --> 0.495406).  Saving model ...
# ----------------------------------------
# Epoch:12	 Training Loss:1.064102	 Validation Loss: 0.435726	 Accuracy: 0.975834
# Validation loss decreased (0.495406 --> 0.435726).  Saving model ...
# ----------------------------------------
# Epoch:13	 Training Loss:1.080686	 Validation Loss: 0.657701	 Accuracy: 0.949167
# Epoch:14	 Training Loss:1.077140	 Validation Loss: 0.762234	 Accuracy: 0.955834
# Epoch:15	 Training Loss:1.026809	 Validation Loss: 0.718816	 Accuracy: 0.959167
# Epoch:16	 Training Loss:0.956851	 Validation Loss: 6.084976	 Accuracy: 0.733334
# Epoch:17	 Training Loss:0.953355	 Validation Loss: 2.832351	 Accuracy: 0.756668
# Epoch:18	 Training Loss:0.895552	 Validation Loss: 0.537355	 Accuracy: 0.968334
# Epoch:19	 Training Loss:0.830887	 Validation Loss: 0.820979	 Accuracy: 0.940001
# Epoch:20	 Training Loss:0.878986	 Validation Loss: 0.301700	 Accuracy: 0.988333
# Validation loss decreased (0.435726 --> 0.301700).  Saving model ...
# ----------------------------------------
# Epoch:21	 Training Loss:0.813334	 Validation Loss: 0.443384	 Accuracy: 0.975834
# Epoch:22	 Training Loss:0.888899	 Validation Loss: 0.360442	 Accuracy: 0.983333
# Epoch:23	 Training Loss:0.913601	 Validation Loss: 0.321210	 Accuracy: 0.981667
# Epoch:24	 Training Loss:0.812635	 Validation Loss: 1.055854	 Accuracy: 0.935001
# Epoch:25	 Training Loss:0.723639	 Validation Loss: 0.285408	 Accuracy: 0.986667
# Validation loss decreased (0.301700 --> 0.285408).  Saving model ...
# ----------------------------------------
# Epoch:26	 Training Loss:0.802084	 Validation Loss: 0.316527	 Accuracy: 0.984167
# Epoch:27	 Training Loss:0.794395	 Validation Loss: 0.323990	 Accuracy: 0.982500
# Epoch:28	 Training Loss:0.763838	 Validation Loss: 0.309128	 Accuracy: 0.986667
# Epoch    30: reducing learning rate of group 0 to 1.0000e-04.
# Epoch:29	 Training Loss:0.769188	 Validation Loss: 0.527570	 Accuracy: 0.972500
# Epoch:30	 Training Loss:0.626387	 Validation Loss: 0.355391	 Accuracy: 0.983333
# Epoch:31	 Training Loss:0.611156	 Validation Loss: 0.280682	 Accuracy: 0.987500
# Validation loss decreased (0.285408 --> 0.280682).  Saving model ...
# ----------------------------------------
# Epoch:32	 Training Loss:0.630069	 Validation Loss: 0.287341	 Accuracy: 0.985833
# Epoch:33	 Training Loss:0.628809	 Validation Loss: 0.238539	 Accuracy: 0.988333
# Validation loss decreased (0.280682 --> 0.238539).  Saving model ...
# ----------------------------------------
# Epoch:34	 Training Loss:0.580135	 Validation Loss: 0.239632	 Accuracy: 0.989167
# Epoch:35	 Training Loss:0.525639	 Validation Loss: 0.228564	 Accuracy: 0.988333
# Validation loss decreased (0.238539 --> 0.228564).  Saving model ...
# ----------------------------------------
# Epoch:36	 Training Loss:0.518835	 Validation Loss: 0.243781	 Accuracy: 0.988333
# Epoch:37	 Training Loss:0.572342	 Validation Loss: 0.242380	 Accuracy: 0.988333
# Epoch:38	 Training Loss:0.560128	 Validation Loss: 0.248708	 Accuracy: 0.988333
# Epoch:39	 Training Loss:0.572192	 Validation Loss: 0.247985	 Accuracy: 0.987500
# Epoch    41: reducing learning rate of group 0 to 1.0000e-05.
# Epoch:40	 Training Loss:0.553609	 Validation Loss: 0.238405	 Accuracy: 0.988333
# Epoch:41	 Training Loss:0.543797	 Validation Loss: 0.241960	 Accuracy: 0.987500
# Epoch:42	 Training Loss:0.504683	 Validation Loss: 0.275414	 Accuracy: 0.987500
# Epoch:43	 Training Loss:0.566257	 Validation Loss: 0.257437	 Accuracy: 0.987500
# Epoch:44	 Training Loss:0.537689	 Validation Loss: 0.248891	 Accuracy: 0.988333
# Epoch:45	 Training Loss:0.571936	 Validation Loss: 0.251426	 Accuracy: 0.987500
# Epoch    47: reducing learning rate of group 0 to 1.0000e-06.
# Epoch:46	 Training Loss:0.632697	 Validation Loss: 0.307046	 Accuracy: 0.984167
# Epoch:47	 Training Loss:0.536668	 Validation Loss: 0.242171	 Accuracy: 0.988333
# Epoch:48	 Training Loss:0.513233	 Validation Loss: 0.251814	 Accuracy: 0.988333
# Epoch:49	 Training Loss:0.479516	 Validation Loss: 0.255739	 Accuracy: 0.988333
# Epoch:50	 Training Loss:0.566958	 Validation Loss: 0.235769	 Accuracy: 0.988334
# Epoch:51	 Training Loss:0.579123	 Validation Loss: 0.292007	 Accuracy: 0.985833
# Epoch:52	 Training Loss:0.548849	 Validation Loss: 0.238752	 Accuracy: 0.988334
# Epoch    54: reducing learning rate of group 0 to 1.0000e-07.
# Epoch:53	 Training Loss:0.571372	 Validation Loss: 0.259450	 Accuracy: 0.987500
# Epoch:54	 Training Loss:0.594837	 Validation Loss: 0.234497	 Accuracy: 0.989167
# Epoch:55	 Training Loss:0.557784	 Validation Loss: 0.243744	 Accuracy: 0.987500
# Epoch:56	 Training Loss:0.577815	 Validation Loss: 0.280454	 Accuracy: 0.985833
# Epoch    58: reducing learning rate of group 0 to 1.0000e-08.
# Epoch:57	 Training Loss:0.504192	 Validation Loss: 0.248043	 Accuracy: 0.988333
# Epoch:58	 Training Loss:0.559821	 Validation Loss: 0.301267	 Accuracy: 0.985833
# Epoch:59	 Training Loss:0.562188	 Validation Loss: 0.245000	 Accuracy: 0.989167
# Epoch:60	 Training Loss:0.537165	 Validation Loss: 0.240766	 Accuracy: 0.988333
# Epoch:61	 Training Loss:0.553588	 Validation Loss: 0.242598	 Accuracy: 0.988333
# Epoch:62	 Training Loss:0.559064	 Validation Loss: 0.231928	 Accuracy: 0.990000
# Epoch:63	 Training Loss:0.535707	 Validation Loss: 0.261538	 Accuracy: 0.988333
# Epoch:64	 Training Loss:0.552816	 Validation Loss: 0.242673	 Accuracy: 0.988333
# Epoch:65	 Training Loss:0.551394	 Validation Loss: 0.235037	 Accuracy: 0.988333
# Epoch:66	 Training Loss:0.557266	 Validation Loss: 0.265555	 Accuracy: 0.987500
# Epoch:67	 Training Loss:0.589425	 Validation Loss: 0.299044	 Accuracy: 0.985000
# Epoch:68	 Training Loss:0.569105	 Validation Loss: 0.280407	 Accuracy: 0.985833
# Epoch:69	 Training Loss:0.551289	 Validation Loss: 0.256223	 Accuracy: 0.988333
# Epoch:70	 Training Loss:0.521060	 Validation Loss: 0.252241	 Accuracy: 0.987500
# Epoch:71	 Training Loss:0.514343	 Validation Loss: 0.239891	 Accuracy: 0.988333
# Epoch:72	 Training Loss:0.601851	 Validation Loss: 0.264164	 Accuracy: 0.987500
# Epoch:73	 Training Loss:0.514587	 Validation Loss: 0.285661	 Accuracy: 0.985833
# Epoch:74	 Training Loss:0.552538	 Validation Loss: 0.259925	 Accuracy: 0.988333
# Epoch:75	 Training Loss:0.540403	 Validation Loss: 0.242978	 Accuracy: 0.988334
# Epoch:76	 Training Loss:0.555387	 Validation Loss: 0.240420	 Accuracy: 0.988334
# Epoch:77	 Training Loss:0.558525	 Validation Loss: 0.268446	 Accuracy: 0.986667
# Epoch:78	 Training Loss:0.572375	 Validation Loss: 0.265080	 Accuracy: 0.986667
# Epoch:79	 Training Loss:0.585313	 Validation Loss: 0.242621	 Accuracy: 0.988333
# Epoch:80	 Training Loss:0.516237	 Validation Loss: 0.259309	 Accuracy: 0.987500
# Epoch:81	 Training Loss:0.581375	 Validation Loss: 0.244391	 Accuracy: 0.988333
# Epoch:82	 Training Loss:0.519048	 Validation Loss: 0.273644	 Accuracy: 0.986667
# Epoch:83	 Training Loss:0.575326	 Validation Loss: 0.250390	 Accuracy: 0.987500
# Epoch:84	 Training Loss:0.573343	 Validation Loss: 0.240091	 Accuracy: 0.989167
# Epoch:85	 Training Loss:0.549447	 Validation Loss: 0.245085	 Accuracy: 0.988333
# Epoch:86	 Training Loss:0.532844	 Validation Loss: 0.260506	 Accuracy: 0.987500
# Epoch:87	 Training Loss:0.572694	 Validation Loss: 0.258193	 Accuracy: 0.987500
# Epoch:88	 Training Loss:0.542732	 Validation Loss: 0.333086	 Accuracy: 0.984167
# Epoch:89	 Training Loss:0.611612	 Validation Loss: 0.275921	 Accuracy: 0.986667
# Epoch:90	 Training Loss:0.573095	 Validation Loss: 0.230903	 Accuracy: 0.988334
# Epoch:91	 Training Loss:0.531883	 Validation Loss: 0.244735	 Accuracy: 0.988334
# Epoch:92	 Training Loss:0.531016	 Validation Loss: 0.277829	 Accuracy: 0.986667
# Epoch:93	 Training Loss:0.593971	 Validation Loss: 0.256519	 Accuracy: 0.987500
# Epoch:94	 Training Loss:0.576942	 Validation Loss: 0.237551	 Accuracy: 0.988333
# Epoch:95	 Training Loss:0.557798	 Validation Loss: 0.233122	 Accuracy: 0.989167
# Epoch:96	 Training Loss:0.517726	 Validation Loss: 0.236902	 Accuracy: 0.988333
# Epoch:97	 Training Loss:0.556552	 Validation Loss: 0.257541	 Accuracy: 0.987500
# Epoch:98	 Training Loss:0.553528	 Validation Loss: 0.238160	 Accuracy: 0.989167
# Epoch:99	 Training Loss:0.577026	 Validation Loss: 0.252853	 Accuracy: 0.987500
# Epoch:100	 Training Loss:0.564769	 Validation Loss: 0.294428	 Accuracy: 0.985000
# Epoch:101	 Training Loss:0.528917	 Validation Loss: 0.241233	 Accuracy: 0.988333
# Epoch:102	 Training Loss:0.524429	 Validation Loss: 0.239311	 Accuracy: 0.988334
# Epoch:103	 Training Loss:0.556536	 Validation Loss: 0.244200	 Accuracy: 0.987500
# Epoch:104	 Training Loss:0.522916	 Validation Loss: 0.245622	 Accuracy: 0.987500
# Epoch:105	 Training Loss:0.573371	 Validation Loss: 0.276172	 Accuracy: 0.985833
# Epoch:106	 Training Loss:0.535359	 Validation Loss: 0.237670	 Accuracy: 0.989167
# Epoch:107	 Training Loss:0.666898	 Validation Loss: 0.267062	 Accuracy: 0.986667
# Epoch:108	 Training Loss:0.526944	 Validation Loss: 0.275141	 Accuracy: 0.986667
# Epoch:109	 Training Loss:0.575897	 Validation Loss: 0.265692	 Accuracy: 0.986667
# Epoch:110	 Training Loss:0.506677	 Validation Loss: 0.243998	 Accuracy: 0.988333
# Epoch:111	 Training Loss:0.519978	 Validation Loss: 0.245235	 Accuracy: 0.988333
# Epoch:112	 Training Loss:0.470536	 Validation Loss: 0.236455	 Accuracy: 0.988334
# Epoch:113	 Training Loss:0.621995	 Validation Loss: 0.263934	 Accuracy: 0.987500
# Epoch:114	 Training Loss:0.529951	 Validation Loss: 0.257038	 Accuracy: 0.987500
# Epoch:115	 Training Loss:0.540993	 Validation Loss: 0.248849	 Accuracy: 0.988333
# Epoch:116	 Training Loss:0.546630	 Validation Loss: 0.271399	 Accuracy: 0.987500
# Epoch:117	 Training Loss:0.525231	 Validation Loss: 0.238172	 Accuracy: 0.988333
# Epoch:118	 Training Loss:0.531632	 Validation Loss: 0.263350	 Accuracy: 0.987500
# Epoch:119	 Training Loss:0.571111	 Validation Loss: 0.240455	 Accuracy: 0.989167
# Epoch:120	 Training Loss:0.605941	 Validation Loss: 0.242405	 Accuracy: 0.988333
# Epoch:121	 Training Loss:0.559855	 Validation Loss: 0.250890	 Accuracy: 0.988333
# Epoch:122	 Training Loss:0.546435	 Validation Loss: 0.262132	 Accuracy: 0.988333
# Epoch:123	 Training Loss:0.619997	 Validation Loss: 0.265996	 Accuracy: 0.987500
# Epoch:124	 Training Loss:0.539859	 Validation Loss: 0.272301	 Accuracy: 0.987500
# Epoch:125	 Training Loss:0.563320	 Validation Loss: 0.287539	 Accuracy: 0.986667
# Epoch:126	 Training Loss:0.526967	 Validation Loss: 0.303288	 Accuracy: 0.985000
# Epoch:127	 Training Loss:0.552759	 Validation Loss: 0.235135	 Accuracy: 0.988334
# Epoch:128	 Training Loss:0.567002	 Validation Loss: 0.243717	 Accuracy: 0.988333
# Epoch:129	 Training Loss:0.574361	 Validation Loss: 0.247741	 Accuracy: 0.987500
# Epoch:130	 Training Loss:0.611299	 Validation Loss: 0.237556	 Accuracy: 0.988333
# Epoch:131	 Training Loss:0.578282	 Validation Loss: 0.253461	 Accuracy: 0.988333
# Epoch:132	 Training Loss:0.534155	 Validation Loss: 0.235544	 Accuracy: 0.988333
# Epoch:133	 Training Loss:0.550264	 Validation Loss: 0.240861	 Accuracy: 0.988333
# Epoch:134	 Training Loss:0.603928	 Validation Loss: 0.254682	 Accuracy: 0.988333
# Epoch:135	 Training Loss:0.522299	 Validation Loss: 0.256752	 Accuracy: 0.987500
# Epoch:136	 Training Loss:0.533527	 Validation Loss: 0.249367	 Accuracy: 0.988333
# Epoch:137	 Training Loss:0.574050	 Validation Loss: 0.233866	 Accuracy: 0.989167
# Epoch:138	 Training Loss:0.557159	 Validation Loss: 0.231444	 Accuracy: 0.989167
# Epoch:139	 Training Loss:0.608458	 Validation Loss: 0.261389	 Accuracy: 0.987500
# Epoch:140	 Training Loss:0.590962	 Validation Loss: 0.252860	 Accuracy: 0.988333
# Epoch:141	 Training Loss:0.572052	 Validation Loss: 0.265007	 Accuracy: 0.988333
# Epoch:142	 Training Loss:0.552598	 Validation Loss: 0.293499	 Accuracy: 0.985000
# Epoch:143	 Training Loss:0.592881	 Validation Loss: 0.287748	 Accuracy: 0.985833
# Epoch:144	 Training Loss:0.559800	 Validation Loss: 0.236873	 Accuracy: 0.989167
# Epoch:145	 Training Loss:0.503188	 Validation Loss: 0.237576	 Accuracy: 0.988333
# Epoch:146	 Training Loss:0.557791	 Validation Loss: 0.243525	 Accuracy: 0.988333
# Epoch:147	 Training Loss:0.610500	 Validation Loss: 0.276293	 Accuracy: 0.986667
# Epoch:148	 Training Loss:0.560889	 Validation Loss: 0.262024	 Accuracy: 0.987500
# Epoch:149	 Training Loss:0.545530	 Validation Loss: 0.284971	 Accuracy: 0.985833
# Epoch:150	 Training Loss:0.592278	 Validation Loss: 0.262957	 Accuracy: 0.987500

# %%
plt.plot(train_losses, label='Training loss')
plt.plot(valid_losses, label='Validation loss')
plt.scatter(35, 0.222564, c='red', label='Model stopping point')
plt.legend(frameon=False)

# %% [markdown]
# #### Make Predictions and Evaluate Model

# %%
# Load weights to model
weights = torch.load('../model_checkPoints/densenet121_model_2Class_pn_covid.pth')
model.load_state_dict(weights)
# Out:
# <All keys matched successfully>

# %%
final_predicted_array = []
groundTruth = []

# Evaluation mode
with torch.no_grad():
    model.eval()
    for data, target in validloader:
        data, target = data.to(device, dtype=torch.float), target.to(device, dtype=torch.long)
        groundTruth.extend(target.data.cpu().numpy())
        output = model(data)
        ps = torch.exp(F.log_softmax(output, dim=1))
        top_p, top_class = ps.topk(1, dim=1)
        final_predicted_array.extend(top_class.data.cpu().numpy())

# %%
target_names = ["Pneumonia", "Covid"]
print(classification_report(groundTruth, final_predicted_array, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#    Pneumonia       1.00      0.98      0.99       613
#        Covid       0.98      1.00      0.99       587
#
#     accuracy                           0.99      1200
#    macro avg       0.99      0.99      0.99      1200
# weighted avg       0.99      0.99      0.99      1200

# %%
fpr, tpr, thresholds = roc_curve(groundTruth, final_predicted_array)
auc = roc_auc_score(groundTruth, final_predicted_array)
print("TPR: {} \t FPR: {}".format(fpr, tpr))
print("AUC on Test Set:",auc)
# Out:
# TPR: [0.        0.0228385 1.       ] 	 FPR: [0. 1. 1.]
# AUC on Test Set: 0.9885807504078303

# %%
from plot_metric.functions import BinaryClassification
bc = BinaryClassification(groundTruth, final_predicted_array, labels=["Pneumonia", "Covid"])

plt.figure(figsize=(5,5))
bc.plot_roc_curve()
plt.show()
plt.savefig('covid_pneumonia_roc.png')
