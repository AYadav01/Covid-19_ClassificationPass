# %%
from tqdm import tqdm
from skimage import io
from skimage.transform import resize
from skimage.color import rgb2gray
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os
import nrrd
from sklearn.model_selection import train_test_split
import torch
from torch import nn
import torch.nn.functional as F
from sklearn.preprocessing import StandardScaler
from torch.utils import data
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from torchvision import datasets, transforms, models

# %% [markdown]
# #### Load Data

# %%
x_train, header = nrrd.read("../processed/normal_abnormal/x_train.nrrd")
y_train, header = nrrd.read("../processed/normal_abnormal/y_train.nrrd")
x_valid, header = nrrd.read("../processed/normal_abnormal/x_valid.nrrd")
y_valid, header = nrrd.read("../processed/normal_abnormal/y_valid.nrrd")

# %%
# Transform to torch tensors
tensor_train_x = torch.Tensor(x_train)
tensor_train_y = torch.Tensor(y_train)
tensor_valid_x = torch.Tensor(x_valid)
tensor_valid_y = torch.Tensor(y_valid)

trainset = data.TensorDataset(tensor_train_x, tensor_train_y)
validset = data.TensorDataset(tensor_valid_x, tensor_valid_y)
trainloader = data.DataLoader(trainset, batch_size=5, shuffle=True)
validloader = data.DataLoader(validset, batch_size=5, shuffle=True)

# %% [markdown]
# #### Check for CUDA

# %%
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    device = torch.device("cpu")
    print("Running on CPU")
else:
    device = torch.device("cuda:0")
    print("CUDA is available!")
# Out:
# CUDA is available!

# %%
model = models.densenet121(pretrained=False)

# %% [markdown]
# ```python
# for param in model.parameters():
#     param.requires_grad = False
# ```

# %%
model.features.conv0 = nn.Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)

# %%
classifier = nn.Sequential(nn.Linear(1024, 256),
                                 nn.ReLU(),
                                 nn.Dropout(0.2),
                                 nn.Linear(256, 2))

model.classifier = classifier

# %%
# Put model on CUDA
model.to(device)
# Out:
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace=True)
#     (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): _Transition(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock2): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): _Transition(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock3): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): _Transition(
#       (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock4): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (norm5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=1024, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=256, out_features=2, bias=True)
#   )
# )

# %%
import torch.optim as optim
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=3, verbose=True)

# %% [markdown]
# #### Train Model

# %%
n_epochs = 200
valid_loss_min = np.Inf
train_losses, valid_losses = [], []

for epoch in range(n_epochs):
    # Define Constants
    train_loss = 0.0
    valid_loss = 0.0
    accuracy = 0.0
    epoch_loss = []
   
    for data, target in trainloader:
        # Put data on GPU
        data, target = data.to(device, dtype=torch.float), target.to(device, dtype=torch.long)
        optimizer.zero_grad()
        output = model(data)
        # Compute loss
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        epoch_loss.append(float(loss.item()*data.size(0)))
        train_loss += loss.item()*data.size(0)
    
    # Check if learning rate needs to be updated
    scheduler.step(np.mean(epoch_loss))
    with torch.no_grad():
        model.eval() # Turn dropout off
        for data, target in validloader:
            data, target = data.to(device, dtype=torch.float), target.to(device, dtype=torch.long)
            output = model(data)
            loss = criterion(output, target)
            valid_loss += loss.item()*data.size(0)
            # Calculating accuracy
            ps = torch.exp(F.log_softmax(output, dim=1))
            top_p, top_class = ps.topk(1, dim=1)
            equals = top_class == target.view(*top_class.shape)
            accuracy += torch.mean(equals.type(torch.FloatTensor))
            
    model.train()
    # Calculate average loss and accuracy
    train_loss = train_loss/len(trainloader)
    valid_loss = valid_loss/len(validloader)
    accuracy = accuracy/len(validloader)
    train_losses.append(train_loss)
    valid_losses.append(valid_loss)
    
    print("Epoch:{}\t Training Loss:{:.6f}\t Validation Loss: {:.6f}\t Accuracy: {:.6f}".format(epoch, train_loss, valid_loss, accuracy))
    # Save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print("Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...".format(valid_loss_min, valid_loss))
        print("-"*40)
        # Save model
        torch.save(model.state_dict(), 'model_checkpoints/densenet121_model_2Class_normal_abnormal.pth')
        valid_loss_min = valid_loss
# Out:
# Epoch:0	 Training Loss:3.314013	 Validation Loss: 3.008164	 Accuracy: 0.755834
# Validation loss decreased (inf --> 3.008164).  Saving model ...
# ----------------------------------------
# Epoch:1	 Training Loss:2.943086	 Validation Loss: 2.564660	 Accuracy: 0.790834
# Validation loss decreased (3.008164 --> 2.564660).  Saving model ...
# ----------------------------------------
# Epoch:2	 Training Loss:2.643438	 Validation Loss: 2.326380	 Accuracy: 0.818334
# Validation loss decreased (2.564660 --> 2.326380).  Saving model ...
# ----------------------------------------
# Epoch:3	 Training Loss:2.457020	 Validation Loss: 2.377430	 Accuracy: 0.794168
# Epoch:4	 Training Loss:2.294087	 Validation Loss: 1.975869	 Accuracy: 0.833334
# Validation loss decreased (2.326380 --> 1.975869).  Saving model ...
# ----------------------------------------
# Epoch:5	 Training Loss:2.224511	 Validation Loss: 2.029434	 Accuracy: 0.829168
# Epoch:6	 Training Loss:2.169232	 Validation Loss: 2.319566	 Accuracy: 0.786667
# Epoch:7	 Training Loss:2.071773	 Validation Loss: 2.462938	 Accuracy: 0.769168
# Epoch:8	 Training Loss:2.033203	 Validation Loss: 2.154968	 Accuracy: 0.805835
# Epoch:9	 Training Loss:2.015101	 Validation Loss: 1.650269	 Accuracy: 0.864168
# Validation loss decreased (1.975869 --> 1.650269).  Saving model ...
# ----------------------------------------
# Epoch:10	 Training Loss:2.008465	 Validation Loss: 2.035125	 Accuracy: 0.820001
# Epoch:11	 Training Loss:1.905696	 Validation Loss: 2.271814	 Accuracy: 0.794168
# Epoch:12	 Training Loss:1.956172	 Validation Loss: 1.612723	 Accuracy: 0.865834
# Validation loss decreased (1.650269 --> 1.612723).  Saving model ...
# ----------------------------------------
# Epoch:13	 Training Loss:1.866252	 Validation Loss: 1.665736	 Accuracy: 0.866668
# Epoch:14	 Training Loss:1.803241	 Validation Loss: 1.685422	 Accuracy: 0.867501
# Epoch:15	 Training Loss:1.839214	 Validation Loss: 1.474602	 Accuracy: 0.884167
# Validation loss decreased (1.612723 --> 1.474602).  Saving model ...
# ----------------------------------------
# Epoch:16	 Training Loss:1.829603	 Validation Loss: 1.405630	 Accuracy: 0.885834
# Validation loss decreased (1.474602 --> 1.405630).  Saving model ...
# ----------------------------------------
# Epoch:17	 Training Loss:1.702341	 Validation Loss: 1.480937	 Accuracy: 0.888334
# Epoch:18	 Training Loss:1.690775	 Validation Loss: 1.425748	 Accuracy: 0.878334
# Epoch:19	 Training Loss:1.653768	 Validation Loss: 2.576629	 Accuracy: 0.783334
# Epoch:20	 Training Loss:1.632143	 Validation Loss: 1.382113	 Accuracy: 0.890834
# Validation loss decreased (1.405630 --> 1.382113).  Saving model ...
# ----------------------------------------
# Epoch:21	 Training Loss:1.709391	 Validation Loss: 1.540675	 Accuracy: 0.880001
# Epoch:22	 Training Loss:1.640506	 Validation Loss: 1.483889	 Accuracy: 0.890001
# Epoch:23	 Training Loss:1.616151	 Validation Loss: 1.677961	 Accuracy: 0.860834
# Epoch:24	 Training Loss:1.540402	 Validation Loss: 1.454609	 Accuracy: 0.889168
# Epoch:25	 Training Loss:1.520550	 Validation Loss: 1.348010	 Accuracy: 0.900001
# Validation loss decreased (1.382113 --> 1.348010).  Saving model ...
# ----------------------------------------
# Epoch:26	 Training Loss:1.486204	 Validation Loss: 3.011691	 Accuracy: 0.744167
# Epoch:27	 Training Loss:1.553708	 Validation Loss: 1.468591	 Accuracy: 0.887501
# Epoch:28	 Training Loss:1.432459	 Validation Loss: 1.508053	 Accuracy: 0.883334
# Epoch:29	 Training Loss:1.525098	 Validation Loss: 1.622052	 Accuracy: 0.871668
# Epoch:30	 Training Loss:1.446831	 Validation Loss: 1.461186	 Accuracy: 0.886667
# Epoch:31	 Training Loss:1.443138	 Validation Loss: 1.414775	 Accuracy: 0.895001
# Epoch    33: reducing learning rate of group 0 to 1.0000e-04.
# Epoch:32	 Training Loss:1.465773	 Validation Loss: 1.911340	 Accuracy: 0.835834
# Epoch:33	 Training Loss:1.288672	 Validation Loss: 1.260724	 Accuracy: 0.905001
# Validation loss decreased (1.348010 --> 1.260724).  Saving model ...
# ----------------------------------------
# Epoch:34	 Training Loss:1.240881	 Validation Loss: 1.265443	 Accuracy: 0.903334
# Epoch:35	 Training Loss:1.254252	 Validation Loss: 1.250011	 Accuracy: 0.911667
# Validation loss decreased (1.260724 --> 1.250011).  Saving model ...
# ----------------------------------------
# Epoch:36	 Training Loss:1.181631	 Validation Loss: 1.405107	 Accuracy: 0.895834
# Epoch:37	 Training Loss:1.286237	 Validation Loss: 1.234325	 Accuracy: 0.905001
# Validation loss decreased (1.250011 --> 1.234325).  Saving model ...
# ----------------------------------------
# Epoch:38	 Training Loss:1.139292	 Validation Loss: 1.243372	 Accuracy: 0.908334
# Epoch:39	 Training Loss:1.145327	 Validation Loss: 1.236292	 Accuracy: 0.906667
# Epoch:40	 Training Loss:1.288206	 Validation Loss: 1.266947	 Accuracy: 0.904167
# Epoch:41	 Training Loss:1.199566	 Validation Loss: 1.228466	 Accuracy: 0.910001
# Validation loss decreased (1.234325 --> 1.228466).  Saving model ...
# ----------------------------------------
# Epoch    43: reducing learning rate of group 0 to 1.0000e-05.
# Epoch:42	 Training Loss:1.166105	 Validation Loss: 1.270707	 Accuracy: 0.908334
# Epoch:43	 Training Loss:1.078986	 Validation Loss: 1.248193	 Accuracy: 0.913334
# Epoch:44	 Training Loss:1.101917	 Validation Loss: 1.236231	 Accuracy: 0.911668
# Epoch:45	 Training Loss:1.124765	 Validation Loss: 1.235255	 Accuracy: 0.912501
# Epoch:46	 Training Loss:1.200340	 Validation Loss: 1.275378	 Accuracy: 0.911667
# Epoch    48: reducing learning rate of group 0 to 1.0000e-06.
# Epoch:47	 Training Loss:1.168154	 Validation Loss: 1.317538	 Accuracy: 0.900834
# Epoch:48	 Training Loss:1.111896	 Validation Loss: 1.288805	 Accuracy: 0.902501
# Epoch:49	 Training Loss:1.178470	 Validation Loss: 1.278719	 Accuracy: 0.901667
# Epoch:50	 Training Loss:1.120850	 Validation Loss: 1.257698	 Accuracy: 0.910001
# Epoch    52: reducing learning rate of group 0 to 1.0000e-07.
# Epoch:51	 Training Loss:1.095573	 Validation Loss: 1.284231	 Accuracy: 0.908334
# Epoch:52	 Training Loss:1.115309	 Validation Loss: 1.257122	 Accuracy: 0.912501
# Epoch:53	 Training Loss:1.191650	 Validation Loss: 1.248725	 Accuracy: 0.905834
# Epoch:54	 Training Loss:1.139060	 Validation Loss: 1.263323	 Accuracy: 0.907501
# Epoch    56: reducing learning rate of group 0 to 1.0000e-08.
# Epoch:55	 Training Loss:1.107473	 Validation Loss: 1.249091	 Accuracy: 0.910834
# Epoch:56	 Training Loss:1.154539	 Validation Loss: 1.228285	 Accuracy: 0.912501
# Validation loss decreased (1.228466 --> 1.228285).  Saving model ...
# ----------------------------------------
# Epoch:57	 Training Loss:1.169790	 Validation Loss: 1.259922	 Accuracy: 0.906667
# Epoch:58	 Training Loss:1.110170	 Validation Loss: 1.232196	 Accuracy: 0.911667
# Epoch:59	 Training Loss:1.075664	 Validation Loss: 1.330469	 Accuracy: 0.903334
# Epoch:60	 Training Loss:1.120473	 Validation Loss: 1.428564	 Accuracy: 0.886667
# Epoch:61	 Training Loss:1.146741	 Validation Loss: 1.243621	 Accuracy: 0.910834
# Epoch:62	 Training Loss:1.176237	 Validation Loss: 1.242988	 Accuracy: 0.911667
# Epoch:63	 Training Loss:1.192310	 Validation Loss: 1.231984	 Accuracy: 0.913334
# Epoch:64	 Training Loss:1.185600	 Validation Loss: 1.235319	 Accuracy: 0.910001
# Epoch:65	 Training Loss:1.138825	 Validation Loss: 1.275026	 Accuracy: 0.909167
# Epoch:66	 Training Loss:1.106430	 Validation Loss: 1.219183	 Accuracy: 0.914167
# Validation loss decreased (1.228285 --> 1.219183).  Saving model ...
# ----------------------------------------
# Epoch:67	 Training Loss:1.191471	 Validation Loss: 1.231223	 Accuracy: 0.914168
# Epoch:68	 Training Loss:1.168947	 Validation Loss: 1.547058	 Accuracy: 0.884167
# Epoch:69	 Training Loss:1.209067	 Validation Loss: 1.250972	 Accuracy: 0.909167
# Epoch:70	 Training Loss:1.169777	 Validation Loss: 1.391616	 Accuracy: 0.892501
# Epoch:71	 Training Loss:1.172368	 Validation Loss: 1.236265	 Accuracy: 0.910001
# Epoch:72	 Training Loss:1.119946	 Validation Loss: 1.248699	 Accuracy: 0.910001
# Epoch:73	 Training Loss:1.178922	 Validation Loss: 1.279301	 Accuracy: 0.906667
# Epoch:74	 Training Loss:1.173436	 Validation Loss: 1.240789	 Accuracy: 0.909167
# Epoch:75	 Training Loss:1.125140	 Validation Loss: 1.306697	 Accuracy: 0.902501
# Epoch:76	 Training Loss:1.162654	 Validation Loss: 1.262447	 Accuracy: 0.909167
# Epoch:77	 Training Loss:1.135227	 Validation Loss: 1.239854	 Accuracy: 0.910834
# Epoch:78	 Training Loss:1.209682	 Validation Loss: 1.324184	 Accuracy: 0.902501
# Epoch:79	 Training Loss:1.080810	 Validation Loss: 1.245470	 Accuracy: 0.913334
# Epoch:80	 Training Loss:1.084045	 Validation Loss: 1.316612	 Accuracy: 0.905834
# Epoch:81	 Training Loss:1.123603	 Validation Loss: 1.262470	 Accuracy: 0.910834
# Epoch:82	 Training Loss:1.097646	 Validation Loss: 1.234499	 Accuracy: 0.913334
# Epoch:83	 Training Loss:1.082010	 Validation Loss: 1.274568	 Accuracy: 0.911667
# Epoch:84	 Training Loss:1.099762	 Validation Loss: 1.231995	 Accuracy: 0.910001
# Epoch:85	 Training Loss:1.102333	 Validation Loss: 1.235637	 Accuracy: 0.914167
# Epoch:86	 Training Loss:1.107511	 Validation Loss: 1.243002	 Accuracy: 0.910001
# Epoch:87	 Training Loss:1.192289	 Validation Loss: 1.337851	 Accuracy: 0.901667
# Epoch:88	 Training Loss:1.174866	 Validation Loss: 1.233545	 Accuracy: 0.915001
# Epoch:89	 Training Loss:1.108958	 Validation Loss: 1.247053	 Accuracy: 0.910834
# Epoch:90	 Training Loss:1.078761	 Validation Loss: 1.247991	 Accuracy: 0.912501
# Epoch:91	 Training Loss:1.109628	 Validation Loss: 1.284268	 Accuracy: 0.905834
# Epoch:92	 Training Loss:1.115236	 Validation Loss: 1.223289	 Accuracy: 0.910001
# Epoch:93	 Training Loss:1.195075	 Validation Loss: 1.242506	 Accuracy: 0.910001
# Epoch:94	 Training Loss:1.130317	 Validation Loss: 1.251865	 Accuracy: 0.911667
# Epoch:95	 Training Loss:1.111388	 Validation Loss: 1.243076	 Accuracy: 0.913334
# Epoch:96	 Training Loss:1.201646	 Validation Loss: 1.240317	 Accuracy: 0.910834
# Epoch:97	 Training Loss:1.137156	 Validation Loss: 1.247424	 Accuracy: 0.910834
# Epoch:98	 Training Loss:1.154833	 Validation Loss: 1.239884	 Accuracy: 0.913334
# Epoch:99	 Training Loss:1.138683	 Validation Loss: 1.230429	 Accuracy: 0.916667
# Epoch:100	 Training Loss:1.076237	 Validation Loss: 1.210221	 Accuracy: 0.914167
# Validation loss decreased (1.219183 --> 1.210221).  Saving model ...
# ----------------------------------------
# Epoch:101	 Training Loss:1.128371	 Validation Loss: 1.220720	 Accuracy: 0.910001
# Epoch:102	 Training Loss:1.124275	 Validation Loss: 1.278222	 Accuracy: 0.904167
# Epoch:103	 Training Loss:1.119033	 Validation Loss: 1.258625	 Accuracy: 0.910834
# Epoch:104	 Training Loss:1.177215	 Validation Loss: 1.283795	 Accuracy: 0.906667
# Epoch:105	 Training Loss:1.141160	 Validation Loss: 1.245406	 Accuracy: 0.913334
# Epoch:106	 Training Loss:1.148551	 Validation Loss: 1.285900	 Accuracy: 0.903334
# Epoch:107	 Training Loss:1.116723	 Validation Loss: 1.253506	 Accuracy: 0.912501
# Epoch:108	 Training Loss:1.177575	 Validation Loss: 1.310583	 Accuracy: 0.901667
# Epoch:109	 Training Loss:1.144361	 Validation Loss: 1.251769	 Accuracy: 0.912501
# Epoch:110	 Training Loss:1.152351	 Validation Loss: 1.237521	 Accuracy: 0.908334
# Epoch:111	 Training Loss:1.159210	 Validation Loss: 1.239986	 Accuracy: 0.915001
# Epoch:112	 Training Loss:1.215724	 Validation Loss: 1.232816	 Accuracy: 0.911667
# Epoch:113	 Training Loss:1.123483	 Validation Loss: 1.300009	 Accuracy: 0.904167
# Epoch:114	 Training Loss:1.120910	 Validation Loss: 1.281325	 Accuracy: 0.909167

# %%
plt.plot(train_losses, label='Training loss')
plt.plot(valid_losses, label='Validation loss')
plt.scatter(100, 1.210221, c='red', label='Model stopping point')
plt.legend(frameon=False)
plt.savefig('densenet121_2Class_loss_normal_abnormal.png')

# %% [markdown]
# #### Make Predictions and Evaluate Model

# %%
# Load weights to model
weights = torch.load('../model_checkPoints/densenet121_model_2Class_normal_abnormal.pth')
model.load_state_dict(weights)
# Out:
# <All keys matched successfully>

# %%
final_predicted_array = []
groundTruth = []

# Evaluation mode
with torch.no_grad():
    model.eval()
    for data, target in validloader:
        data, target = data.to(device, dtype=torch.float), target.to(device, dtype=torch.long)
        groundTruth.extend(target.data.cpu().numpy())
        output = model(data)
        ps = torch.exp(F.log_softmax(output, dim=1))
        top_p, top_class = ps.topk(1, dim=1)
        final_predicted_array.extend(top_class.data.cpu().numpy())

# %%
target_names = ["Normal", "Abnormal"]
print(classification_report(groundTruth, final_predicted_array, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.91      0.92      0.92       613
#     Abnormal       0.92      0.91      0.91       587
#
#     accuracy                           0.91      1200
#    macro avg       0.91      0.91      0.91      1200
# weighted avg       0.91      0.91      0.91      1200

# %%
fpr, tpr, thresholds = roc_curve(groundTruth, final_predicted_array)
auc = roc_auc_score(groundTruth, final_predicted_array)
#print("TPR: {} \t FPR: {}".format(fpr, tpr))
print("AUC on Test Set:",auc)
# Out:
# TPR: [0.         0.07830343 1.        ] 	 FPR: [0.         0.90630324 1.        ]
# AUC on Test Set: 0.9139999055111984

# %%
from plot_metric.functions import BinaryClassification
bc = BinaryClassification(groundTruth, final_predicted_array, labels=["Pneumonia", "Covid"])

plt.figure(figsize=(5,5))
bc.plot_roc_curve()
plt.show()
plt.savefig('normal_abnormal_roc.png')
